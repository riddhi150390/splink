# %% [markdown]
# # Alias testing

# %% [markdown]
# Need to dedupe a toy dataset with several records (aliases) for the same unique person ID.
#
# _e.g. - John Smith/Jonty Smithington, David Jones/Davy Jones etc._

# %%
from pyspark.context import SparkContext, SparkConf
from pyspark.sql import SparkSession, Window
from pyspark.sql.types import StructType
import pyspark.sql.functions as f

conf = SparkConf()

# Load in a jar that provides extended string comparison functions such as Jaro Winkler.
conf.set('spark.driver.extraClassPath', 'jars/scala-udf-similarity-0.0.6.jar')
conf.set('spark.jars', 'jars/scala-udf-similarity-0.0.6.jar')   

# WARNING:
# These config options are appropriate only if you're running Spark locally!!!
conf.set('spark.driver.memory', '4g')
conf.set("spark.sql.shuffle.partitions", "8") 

sc = SparkContext.getOrCreate(conf=conf)
spark = SparkSession(sc)

 # Register UDFs
from pyspark.sql import types
spark.udf.registerJavaFunction('jaro_winkler_sim', 'uk.gov.moj.dash.linkage.JaroWinklerSimilarity', types.DoubleType())
spark.udf.registerJavaFunction('Dmetaphone', 'uk.gov.moj.dash.linkage.DoubleMetaphone', types.StringType())

# %%
import pandas as pd 
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
# %matplotlib inline

data = {'record_id': [1,2,3,4,5,6],
     'person_id': [1,1,1,2,2,3],
     'first_name': ["John", "Johnny", "Jonty", "David", "Dave", "Jonty"], 
     'surname': ["Smith", "Jones", "Smithington", "Jones", "Jones", "Smith"],
     'birth_year': [1970, 1970, 1980, 1934, 1934, 1980],
     'city': ["Birmingham", "Birmingham", "Oxford", "London", "Reading", "Birmingham"]
}

df = spark.createDataFrame(pd.DataFrame(data))

df.show()
# Out:
# +---------+---------+----------+-----------+----------+----------+
# |record_id|person_id|first_name|    surname|birth_year|      city|
# +---------+---------+----------+-----------+----------+----------+
# |        1|        1|      John|      Smith|      1970|Birmingham|
# |        2|        1|    Johnny|      Jones|      1970|Birmingham|
# |        3|        1|     Jonty|Smithington|      1980|    Oxford|
# |        4|        2|     David|      Jones|      1934|    London|
# |        5|        2|      Dave|      Jones|      1934|   Reading|
# |        6|        3|     Jonty|      Smith|      1980|Birmingham|
# +---------+---------+----------+-----------+----------+----------+

# %% [markdown]
# # Dedupe with `splink`

# %%
from splink.blocking import block_using_rules, cartesian_block
from splink.gammas import add_gammas

# %% [markdown]
# ## 1) All comparisons w/ gammas
#
# - `"unique_id_column_name": "record_id"` - all record comparisons
# - `"unique_id_column_name": "person_id"` - all comparisons between people, but not within person_id groups

# %%
settings = {
    "comparison_columns": [
        {
            "num_levels": 3,
            "col_name": "first_name"
        },
        {
            "num_levels": 3,
            "col_name": "surname"
        },
        {
            "num_levels": 2,
            "col_name": "birth_year",
            "data_type": "numeric"
        },
        {
            "col_name": "city"
        }
    ],
    "blocking_rules": [],
    "link_type": "dedupe_only",
    "unique_id_column_name": "person_id",
    "additional_columns_to_retain": []
}

df_comparison = cartesian_block(settings, spark, df=df)
df_gammas = add_gammas(df_comparison, settings, spark)

df_gammas.toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# /home/jovyan/splink/splink/settings.py:201: UserWarning: You have not specified any blocking rules, meaning all comparisons between the input dataset(s) will be generated and blocking will not be used.For large input datasets, this will generally be computationally intractable because it will generate comparisons equal to the number of rows squared.
#   "You have not specified any blocking rules, meaning all comparisons between the "
# <style  type="text/css" >
#     #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow1_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow1_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow1_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow2_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow2_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow3_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow3_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow3_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow3_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow4_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow4_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow4_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow4_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow5_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow5_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow5_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow5_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow6_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow6_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow6_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow6_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow7_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow7_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow7_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow7_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow8_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow8_col7 {
#             background-color:  #21918c;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow8_col10 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow8_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow9_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow9_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow9_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow9_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow10_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow10_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow10_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow10_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }</style><table id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >John</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >David</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >Smith</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >Jones</td>
#                         <td id="T_86e1cc34_68fb_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_86e1cc34_

# %% [markdown]
# ### Aggregate by `person_id`

# %%
unique_id_col = "person_id"
comparison_cols = [i['col_name'] for i in settings['comparison_columns']]
#custom_cols = [i['custom_column_name'] for i in settings['comparison_columns']] # different kettle of fish

sql_for_cols = [f"collect_set({col}_l) as {col}_l, collect_set({col}_r) as {col}_r, max(gamma_{col}) as gamma_{col}" for col in comparisons_cols]

sql = f"SELECT {unique_id_col}_l, {unique_id_col}_r, {', '.join(sql_for_cols)} FROM df_gammas WHERE {unique_id_col}_l != {unique_id_col}_r GROUP BY {unique_id_col}_l, {unique_id_col}_r"

# %%
df_gammas.createOrReplaceTempView("df_gammas")
df_gammas_agg = spark.sql(sql)

df_gammas_agg.orderBy(["person_id_l", "person_id_r"]).toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# <style  type="text/css" >
#     #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col10 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }</style><table id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >['Johnny', 'Jonty', 'John']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >['Dave', 'David']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >['Smith', 'Jones', 'Smithington']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >['Jones']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col8" class="data row0 col8" >[1980, 1970]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col9" class="data row0 col9" >[1934]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col10" class="data row0 col10" >0</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col11" class="data row0 col11" >['Oxford', 'Birmingham']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col12" class="data row0 col12" >['Reading', 'London']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow0_col13" class="data row0 col13" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col1" class="data row1 col1" >3</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col2" class="data row1 col2" >['Johnny', 'Jonty', 'John']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col3" class="data row1 col3" >['Jonty']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col4" class="data row1 col4" >2</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col5" class="data row1 col5" >['Smith', 'Jones', 'Smithington']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col6" class="data row1 col6" >['Smith']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col8" class="data row1 col8" >[1980, 1970]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col9" class="data row1 col9" >[1980]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col10" class="data row1 col10" >1</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col11" class="data row1 col11" >['Oxford', 'Birmingham']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col12" class="data row1 col12" >['Birmingham']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow1_col13" class="data row1 col13" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col0" class="data row2 col0" >2</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col1" class="data row2 col1" >3</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col2" class="data row2 col2" >['Dave', 'David']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col3" class="data row2 col3" >['Jonty']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col4" class="data row2 col4" >0</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col5" class="data row2 col5" >['Jones']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col6" class="data row2 col6" >['Smith']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col7" class="data row2 col7" >0</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col8" class="data row2 col8" >[1934]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col9" class="data row2 col9" >[1980]</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col10" class="data row2 col10" >0</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_col11" class="data row2 col11" >['Reading', 'London']</td>
#                         <td id="T_89ad8c78_68fb_11ea_8d6e_0ad24c3f4d9frow2_co

# %% [markdown]
# ## 2) Blocking on `birth_year` or `city`

# %%
settings["blocking_rules"]=["l.birth_year = r.birth_year", "l.city = r.city"]

df_comparison2 = block_using_rules(settings, spark, df=df)
df_gammas2 = add_gammas(df_comparison2, settings, spark)

df_gammas2.toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# <style  type="text/css" >
#     #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #21918c;
#             color:  #000000;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >3</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >Jonty</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >Jonty</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >2</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >Smithington</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >Smith</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >1</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col8" class="data row0 col8" >1980</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col9" class="data row0 col9" >1980</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10" class="data row0 col10" >1</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col11" class="data row0 col11" >Oxford</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col12" class="data row0 col12" >Birmingham</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13" class="data row0 col13" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col1" class="data row1 col1" >3</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col2" class="data row1 col2" >John</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col3" class="data row1 col3" >Jonty</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col5" class="data row1 col5" >Smith</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col6" class="data row1 col6" >Smith</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col8" class="data row1 col8" >1970</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col9" class="data row1 col9" >1980</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10" class="data row1 col10" >0</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col11" class="data row1 col11" >Birmingham</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col12" class="data row1 col12" >Birmingham</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13" class="data row1 col13" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col1" class="data row2 col1" >3</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col2" class="data row2 col2" >Johnny</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col3" class="data row2 col3" >Jonty</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col4" class="data row2 col4" >0</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col5" class="data row2 col5" >Jones</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col6" class="data row2 col6" >Smith</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col7" class="data row2 col7" >0</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col8" class="data row2 col8" >1970</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col9" class="data row2 col9" >1980</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col10" class="data row2 col10" >0</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col11" class="data row2 col11" >Birmingham</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col12" class="data row2 col12" >Birmingham</td>
#                         <td id="T_c0ca5098_68ff_11ea_8d6e_0ad24c3f4d9frow2_col13" class="data row2 col13" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Blocking of any kind means aggregated comparisons have no knowledge of other aliases that did not also pass the blocking...

# %%
df_gammas2.createOrReplaceTempView("df_gammas")
df_gammas_agg2 = spark.sql(sql)

df_gammas_agg2.orderBy(["person_id_l", "person_id_r"]).toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# <style  type="text/css" >
#     #T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }</style><table id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >3</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >['Johnny', 'Jonty', 'John']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >['Jonty']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >2</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >['Smith', 'Jones', 'Smithington']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >['Smith']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col8" class="data row0 col8" >[1980, 1970]</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col9" class="data row0 col9" >[1980]</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col10" class="data row0 col10" >1</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col11" class="data row0 col11" >['Oxford', 'Birmingham']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col12" class="data row0 col12" >['Birmingham']</td>
#                         <td id="T_2d596e3c_68fc_11ea_8d6e_0ad24c3f4d9frow0_col13" class="data row0 col13" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 3) Blocking on `surname` or `city`

# %%
settings["blocking_rules"]=["l.surname = r.surname", "l.city = r.city"]

df_comparison3 = block_using_rules(settings, spark, df=df)
df_gammas3 = add_gammas(df_comparison3, settings, spark)

df_gammas3.toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# <style  type="text/css" >
#     #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow3_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow3_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow3_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow3_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >3</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >John</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >Jonty</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >Smith</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >Smith</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col8" class="data row0 col8" >1970</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col9" class="data row0 col9" >1980</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10" class="data row0 col10" >0</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col11" class="data row0 col11" >Birmingham</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col12" class="data row0 col12" >Birmingham</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13" class="data row0 col13" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col1" class="data row1 col1" >2</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col2" class="data row1 col2" >Johnny</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col3" class="data row1 col3" >David</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col5" class="data row1 col5" >Jones</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col6" class="data row1 col6" >Jones</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col8" class="data row1 col8" >1970</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col9" class="data row1 col9" >1934</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10" class="data row1 col10" >0</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col11" class="data row1 col11" >Birmingham</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col12" class="data row1 col12" >London</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13" class="data row1 col13" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col1" class="data row2 col1" >2</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col2" class="data row2 col2" >Johnny</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col3" class="data row2 col3" >Dave</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col4" class="data row2 col4" >0</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col5" class="data row2 col5" >Jones</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col6" class="data row2 col6" >Jones</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col7" class="data row2 col7" >2</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col8" class="data row2 col8" >1970</td>
#                         <td id="T_b000be50_68ff_11ea_8d6e_0ad24c3f4d9frow2_col9" class="data row2 col9" >1934</td>

# %%
df_gammas3.createOrReplaceTempView("df_gammas")
df_gammas_agg3 = spark.sql(sql)

df_gammas_agg3.orderBy(["person_id_l", "person_id_r"]).toPandas().style.background_gradient(cmap='viridis', subset = [f"gamma_{col}" for col in comparisons_cols])
# Out:
# <style  type="text/css" >
#     #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >person_id_l</th>        <th class="col_heading level0 col1" >person_id_r</th>        <th class="col_heading level0 col2" >first_name_l</th>        <th class="col_heading level0 col3" >first_name_r</th>        <th class="col_heading level0 col4" >gamma_first_name</th>        <th class="col_heading level0 col5" >surname_l</th>        <th class="col_heading level0 col6" >surname_r</th>        <th class="col_heading level0 col7" >gamma_surname</th>        <th class="col_heading level0 col8" >birth_year_l</th>        <th class="col_heading level0 col9" >birth_year_r</th>        <th class="col_heading level0 col10" >gamma_birth_year</th>        <th class="col_heading level0 col11" >city_l</th>        <th class="col_heading level0 col12" >city_r</th>        <th class="col_heading level0 col13" >gamma_city</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col1" class="data row0 col1" >2</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col2" class="data row0 col2" >['Johnny']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col3" class="data row0 col3" >['Dave', 'David']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col5" class="data row0 col5" >['Jones']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col6" class="data row0 col6" >['Jones']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col7" class="data row0 col7" >2</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col8" class="data row0 col8" >[1970]</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col9" class="data row0 col9" >[1934]</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col10" class="data row0 col10" >0</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col11" class="data row0 col11" >['Birmingham']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col12" class="data row0 col12" >['Reading', 'London']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow0_col13" class="data row0 col13" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col1" class="data row1 col1" >3</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col2" class="data row1 col2" >['Johnny', 'John']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col3" class="data row1 col3" >['Jonty']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col5" class="data row1 col5" >['Smith', 'Jones']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col6" class="data row1 col6" >['Smith']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col7" class="data row1 col7" >2</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col8" class="data row1 col8" >[1970]</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col9" class="data row1 col9" >[1980]</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col10" class="data row1 col10" >0</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col11" class="data row1 col11" >['Birmingham']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col12" class="data row1 col12" >['Birmingham']</td>
#                         <td id="T_a3028026_68ff_11ea_8d6e_0ad24c3f4d9frow1_col13" class="data row1 col13" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ✅ Person 1 and 2 match on `surname` only, so no problem there.
#
# ❓Person 1 and 3 match on `surname` and `city`, but not `first_name` or `birth_year`.
#
# ❌ However Person 1 also has a further record (`record_id = 6`) where `first_name` and `birth_year` both match (but does not pass the blocking on `city` or `surname`)

# %% [markdown]
# # Problem
#
# - For any comparison between person A and person B, need knowledge of all "aliases" of all fields for each
#
#
# # Solution
#
# - Either perform all possible record comparisons between candidates and then aggregate (as above)
# - Or perform some sort of person-level blocking/comparisons (haven't fully thought through how it would work, but bound to be a total pain)
